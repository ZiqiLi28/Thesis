# %%
# %pip install easyocr
# %pip install opencv-python
# %pip install matplotlib
# %pip install imutils
# %pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image_path = 'car1.jpg'
image = cv2.imread(image_path)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) # Convert to grayscale
equalized = cv2.equalizeHist(gray) # Apply histogram equalization

plt.figure(figsize=(12, 12)) # Make sure the image is not compressed
plt.imshow(equalized, cmap='gray')
plt.axis('off')
plt.show()

# %%
edges = cv2.Canny(equalized, 200, 250, L2gradient=True) # Apply Canny edge detection

plt.figure(figsize=(12, 12))
plt.imshow(edges, cmap='gray')
plt.axis('off')
plt.show()

# %%
contours, _ = cv2.findContours(edges, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE) # Find contours
image_contours = image.copy()
cv2.drawContours(image_contours, contours, -1, (0, 255, 0), 2) # Draw contours

plt.figure(figsize=(12, 12))
plt.imshow(cv2.cvtColor(image_contours, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()
