# %%
# %pip install easyocr
# %pip install opencv-python
# %pip install matplotlib
# %pip install imutils
# %pip install numpy
# Out:
# Requirement already satisfied: easyocr in c:\users\shiyu\appdata\local\programs\python\python312\lib\site-packages (1.7.2)
# Requirement already satisfied: torch in c:\users\shiyu\appdata\local\programs\python\python312\lib\site-packages (from easyocr) (2.5.1)
# Requirement already satisfied: torchvision>=0.5 in c:\users\shiyu\appdata\local\programs\python\python312\lib\site-packages (from easyocr) (0.20.1)
# Requirement already satisfied: opencv-python-headless in c:\users\shiyu\appdata\local\programs\python\python312\lib\site-packages (from easyocr) (4.10.0.84)
# Requirement already satisfied: scipy in c:\users\shiyu\appdata\local\programs\python\python312\lib\site-packages (from easyocr) (1.14.1)
# Requirement already satisfied: numpy in c:\users\shiyu\appdata\local\programs\python\python312\lib\site-packages (from easyocr) (2.1.1)
# Requirement already satisfied: Pillow in c:\users\shiyu\appdata\local\programs\python\python312\lib\site-packages (from easyocr) (10.4.0)
# Requirement already satisfied: scikit-image in c:\users\shiyu\appdata\local\programs\python\python312\lib\site-packages (from easyocr) (0.24.0)
# Requirement already satisfied: python-bidi in c:\users\shiyu\appdata\local\programs\python\python312\lib\site-packages (from easyocr) (0.6.3)
# Requirement already satisfied: PyYAML in c:\users\shiyu\appdata\local\programs\python\python312\lib\site-packages (from easyocr) (6.0.2)
# Requirement already satisfied: Shapely in c:\users\shiyu\appdata\local\programs\python\python312\lib\site-packages (from easyocr) (2.0.6)
# Requirement already satisfied: pyclipper in c:\users\shiyu\appdata\local\programs\python\python312\lib\site-packages (from easyocr) (1.3.0.post6)
# Requirement already satisfied: ninja in c:\users\shiyu\appdata\local\programs\python\python312\lib\site-packages (from easyocr) (1.11.1.1)
# Requirement already satisfied: filelock in c:\users\shiyu\appdata\local\programs\python\python312\lib\site-packages (from torch->easyocr) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\shiyu\appdata\local\programs\python\python312\lib\site-packages (from torch->easyocr) (4.12.2)
# Requirement already satisfied: networkx in c:\users\shiyu\appdata\local\programs\python\python312\lib\site-packages (from torch->easyocr) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\shiyu\appdata\local\programs\python\python312\lib\site-packages (from torch->easyocr) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\shiyu\appdata\local\programs\python\python312\lib\site-packages (from torch->easyocr) (2024.10.0)
# Requirement already satisfied: setuptools in c:\users\shiyu\appdata\local\programs\python\python312\lib\site-packages (from torch->easyocr) (75.3.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\shiyu\appdata\local\programs\python\python312\lib\site-packages (from torch->easyocr) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\shiyu\appdata\local\programs\python\python312\lib\site-packages (from sympy==1.13.1->torch->easyocr) (1.3.0)
# Requirement already satisfied: imageio>=2.33 in c:\users\shiyu\appdata\local\programs\python\python312\lib\site-packages (from scikit-image->easyocr) (2.36.0)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\shiyu\appdata\local\programs\python\python312\lib\site-packages (from scikit-image->easyocr) (2024.9.20)
# Requirement already satisfied: packaging>=21 in c:\users\shiyu\appdata\roaming\python\python312\site-packages (from scikit-image->easyocr) (24.1)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\shiyu\appdata\local\programs\python\python312\lib\site-packages (from scikit-image->easyocr) (0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\shiyu\appdata\local\programs\python\python312\lib\site-packages (from jinja2->torch->easyocr) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: opencv-python in c:\users\shiyu\appdata\local\programs\python\python312\lib\site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\shiyu\appdata\local\programs\python\python312\lib\site-packages (from opencv-python) (2.1.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: matplotlib in c:\users\shiyu\appdata\local\programs\python\python312\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\shiyu\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\shiyu\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\shiyu\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\shiyu\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in c:\users\shiyu\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (2.1.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\shiyu\appdata\roaming\python\python312\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\shiyu\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\shiyu\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\shiyu\appdata\roaming\python\python312\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\shiyu\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: imutils in c:\users\shiyu\appdata\local\programs\python\python312\lib\site-packages (0.5.4)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: numpy in c:\users\shiyu\appdata\local\programs\python\python312\lib\site-packages (2.1.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image_path = 'image.png'
image = cv2.imread(image_path)

plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

equalized = cv2.equalizeHist(gray)

plt.imshow(equalized, cmap='gray')
plt.axis('off')
plt.show()
